# %% [markdown]
# # Airline AI Support Agent
#
# ## Project Goal
# Build a multi-modal airline customer support AI agent using:
# - OpenRouter LLMs
# - Function Calling
# - RAG
# - Voice
# - Vision
# - Gradio UI
#
# ## Tools & Technologies
# - Python
# - OpenRouter
# - Hugging Face
# - FAISS
# - Sentence Transformers
# - Gradio

# %%
# import libraries
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
# Load Environment Variables
load_dotenv()

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

print("Environment variables loaded successfully!")
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# Environment variables loaded successfully!
# True

# %%
# Initialize OpenRouter Client
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=OPENROUTER_API_KEY
)

print("OpenRouter client initialized!")
# Out:
# OpenRouter client initialized!

# %%
# Select Model
MODEL = "openai/gpt-oss-120b:free"

print(f"Using model: {MODEL}")
# Out:
# Using model: openai/gpt-oss-120b:free

# %%
# First AI Response
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {
            "role": "system",
            "content": """
            You are a professional airline customer support AI assistant.

            Rules:
            - Give concise helpful answers
            - Be polite and professional
            - Use bullet points when helpful
            - Keep responses under 150 words
            """
        },
        {
            "role": "user",
            "content": "My flight got delayed by 5 hours. What should I do?"
        }
    ],
    temperature=0.7,
    max_tokens=200
)

print(response.choices[0].message.content)
# Out:
# I’m sorry to hear about the delay. Here’s what you can do:
#
# - **Check your reservation**
#   - Log in to the airline’s app or website to see the updated departure time and any new gate information.
#
# - **Know your rights**
#   - For delays of 5 hours or more, many airlines offer:
#     - A full refund or re‑booking on the next available flight (including on partner airlines)
#     - Compensation or vouchers, depending on the route and local regulations (e.g., EU 261, US DOT)
#
# - **Contact the airline promptly**
#   - Use the app’s chat, call the customer‑service number, or visit the airline desk at the airport. Have your booking reference handy.
#
# - **Consider alternative travel**
#   - If the delay disrupts connections, meetings, or accommodations, ask the agent to arrange a new itinerary or provide a hotel/meal voucher if eligible.
#
# - **Document everything**
# ...
